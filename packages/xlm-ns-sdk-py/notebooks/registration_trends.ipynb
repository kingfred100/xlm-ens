# %% [markdown]
# # Registration trends
# Explore registration counts over time using pandas.

# %%
from xlm_ns_sdk import NameRecord, list_names_frame
records = [
    NameRecord(owner='GAAAA', registered_at=1, expires_at=10, grace_period_ends_at=12, resolver=None),
    NameRecord(owner='GBBBB', registered_at=2, expires_at=12, grace_period_ends_at=14, resolver=None),
]
frame = list_names_frame(records)
frame
