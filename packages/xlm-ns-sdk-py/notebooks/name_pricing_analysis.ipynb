# %% [markdown]
# # Name pricing analysis
# Compare fee components across quote results.

# %%
from xlm_ns_sdk import FeeBreakdown, RegistrationQuote, name_price_analysis
quotes = [
    RegistrationQuote('alice', 1, FeeBreakdown(10, 5, 1), 16, 'XLM', 100, 200, 50),
    RegistrationQuote('bob', 2, FeeBreakdown(10, 0, 1), 11, 'XLM', 100, 200, 50),
]
name_price_analysis(quotes)
